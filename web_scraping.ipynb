# %% [markdown]
# # 📊 Web Scraping - PropyApp
# - Samuel Pérez Hurtado
# - Sebastian Monsalve Gómez
# - David Romero Rodríguez

# %%
import pandas as pd
import requests

# %%
headers = {
    "USER_AGENT": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36",
    "referer": "https://fincaraiz.com.co/"
}

json_data = {
    'filter': {
        'offer': {
            'slug': [
                'sell',
            ],
        },
        'is_new': 'False',
        'locations': {
            'cities': {
                'name': ['Medellín']
            }
        },
    },
    'fields': {
        'exclude': [],
        'include': [
            'area',
            'baths.id',
            'baths.name',
            'client.client_type',
            'client.company_name',
            'client.first_name',
            'client.last_name',
            'garages.name',
            'is_new',
            'locations.cities.name',
            'locations.cities.slug',
            'locations.countries.name',
            'locations.countries.slug',
            'locations.groups.name',
            'locations.groups.slug',
            'locations.groups.subgroups.name',
            'locations.groups.subgroups.slug',
            'locations.location_point',
            'locations.neighbourhoods.name',
            'locations.neighbourhoods.slug',
            'locations.states.name',
            'locations.states.slug',
            'min_area',
            'min_price',
            'price',
            'products.configuration.tag_name',
            'products.label',
            'products.name',
            'products.slug',
            'property_id',
            'fr_property_id',
            'rooms.name',
            'title',
            'property_type.name',
            'offer.name',
            'fr_parent_property_id',
            'stratum.name',
        ],
        'limit': 25,
        'offset': 0,
        'ordering': [],
        'platform': 40,
        'with_algorithm': False,
    }
}

# %%
response = requests.post('https://api.fincaraiz.com.co/document/api/1.0/listing/search', headers=headers, json=json_data, timeout=10)
data = response.json()
data
# Out:
# {'took': 12,
#  'timed_out': False,
#  '_shards': {'total': 3, 'successful': 3, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 26992, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'fr-site-listing',
#     '_id': '5b59f4a2-1208-481a-b451-80fb02fe2e1b',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '50.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '5b59f4a2-1208-481a-b451-80fb02fe2e1b',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '1', 'id': 1},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '210000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Aranjuez',
#          'slug': 'colombia-antioquia-medellín-5502096-aranjuez'},
#         {'name': 'La pinuela',
#          'slug': ['neighbourhood-colombia-05-001-000406']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.55608367919922 6.281782627105713)',
#        'groups': [{'subgroups': {'name': 'NorOriente',
#           'slug': 'colombia-antioquia-medellín-5500103-nororiente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7236417}}},
#    {'_index': 'fr-site-listing',
#     '_id': 'acbbcf61-3022-4d34-87b9-d240ae7cb7b2',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '67.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': 'acbbcf61-3022-4d34-87b9-d240ae7cb7b2',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '340000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Urbanizacion praderas de guayabal',
#          'slug': ['neighbourhood-colombia-05-360-000744']},
#         {'name': 'ITAGUI', 'slug': 'colombia-antioquia-itagui-0-itagui'},
#         {'name': 'Belén Rosales',
#          'slug': ['neighbourhood-5502059-belen_rosales',
#           'colombia-antioquia-medellín-5502059-belén-rosales']},
#         {'name': 'Laureles', 'slug': ['neighbourhood-medellin-05-laureles']},
#         {'name': 'Laureles Nogal',
#          'slug': ['neighbourhood-medellin-05-laureles_nogal']},
#         {'name': 'Belén', 'slug': ['neighbourhood-medellin-05-belen']},
#         {'name': 'Malibu', 'slug': ['neighbourhood-05-medellin-malibu']}],
#        'cities': [{'name': 'Itaguí',
#          'slug': 'colombia-antioquia-5500002-itaguí'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.59156036376953 6.235456943511963)',
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7347494}}},
#    {'_index': 'fr-site-listing',
#     '_id': '7dd6770d-b5f2-4106-81bd-94c39df2999f',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '96.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '7dd6770d-b5f2-4106-81bd-94c39df2999f',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '295000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Aranjuez',
#          'slug': 'colombia-antioquia-medellín-5502096-aranjuez'},
#         {'name': 'La candelaria',
#          'slug': ['neighbourhood-colombia-05-001-001007',
#           'colombia-antioquia-medellín-5502101-la-candelaria']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.5658187866211 6.247637748718262)',
#        'groups': [{'subgroups': {'name': 'NorOriente',
#           'slug': 'colombia-antioquia-medellín-5500103-nororiente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7893613}}},
#    {'_index': 'fr-site-listing',
#     '_id': '4275fdf4-8382-43f4-8e4b-f330031d50a8',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '185.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '4275fdf4-8382-43f4-8e4b-f330031d50a8',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 6'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '2'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '1040000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'ASESORIA INMOBILIARIA Y PROYECTO',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Las palmas',
#          'slug': ['rural_neighbourhood-colombia-05-001-032']},
#         {'name': 'San lucas',
#          'slug': ['neighbourhood-colombia-05-001-001422',
#           'colombia-antioquia-medellín-5502003-san-lucas']}],
#        'cities': [{'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.55524826049805 6.1805192071347825)',
#        'countries': [{'name': 'Colombia',
#          'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7829845}}},
#    {'_index': 'fr-site-listing',
#     '_id': '3840da3b-dffd-4c79-8ce0-6e40ac1da3be',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '65.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '3840da3b-dffd-4c79-8ce0-6e40ac1da3be',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 2'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '1', 'id': 1},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '165000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Manrique',
#          'slug': 'colombia-antioquia-medellín-5502094-manrique'},
#         {'name': 'San isidro',
#          'slug': ['neighbourhood-colombia-05-001-000401']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.5600357055664 6.287129878997803)',
#        'groups': [{'subgroups': {'name': 'NorOriente',
#           'slug': 'colombia-antioquia-medellín-5500103-nororiente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7703615}}},
#    {'_index': 'fr-site-listing',
#     '_id': '02084ce3-327b-44de-bfc4-6a33eae78e52',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '90.0',
#       'rooms': {'name': '2'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '02084ce3-327b-44de-bfc4-6a33eae78e52',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '1', 'id': 1},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '195000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'La Milagrosa',
#          'slug': 'colombia-antioquia-medellín-5502099-la-milagrosa'},
#         {'name': 'La milagrosa',
#          'slug': ['neighbourhood-colombia-05-001-000907',
#           'colombia-antioquia-medellín-5502099-la-milagrosa']},
#         {'name': 'Urbanizacion cataluña',
#          'slug': ['neighbourhood-colombia-05-001-000924']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.55241394042969 6.233801364898682)',
#        'groups': [{'subgroups': {'name': 'NorOriente',
#           'slug': 'colombia-antioquia-medellín-5500103-nororiente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7508440}}},
#    {'_index': 'fr-site-listing',
#     '_id': '0da20ec5-8e25-4e7a-9e04-f1e33536f8b0',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '37.0',
#       'rooms': {'name': '2'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '0da20ec5-8e25-4e7a-9e04-f1e33536f8b0',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '1', 'id': 1},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '145000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Loreto',
#          'slug': 'colombia-antioquia-medellin-0-loreto'},
#         {'name': 'Loreto', 'slug': ['neighbourhood-colombia-05-001-000910']},
#         {'name': 'Asomadera no.3',
#          'slug': ['neighbourhood-colombia-05-001-000915']},
#         {'name': 'Panorama',
#          'slug': ['neighbourhood-colombia-05-001-000914']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.55716705322266 6.23033332824707)',
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7099452}}},
#    {'_index': 'fr-site-listing',
#     '_id': '877904f1-7876-4dd6-b858-457b62018eb6',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '95.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '877904f1-7876-4dd6-b858-457b62018eb6',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '300000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Villa Hermosa',
#          'slug': 'colombia-antioquia-medellín-5502095-villa-hermosa'},
#         {'name': 'Santa ines',
#          'slug': ['neighbourhood-colombia-05-001-000306']},
#         {'name': 'Las granjas',
#          'slug': ['neighbourhood-colombia-05-001-000303']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.54766082763672 6.275725841522217)',
#        'groups': [{'subgroups': {'name': 'NorOriente',
#           'slug': 'colombia-antioquia-medellín-5500103-nororiente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7147191}}},
#    {'_index': 'fr-site-listing',
#     '_id': '03a0f0ef-8241-4241-b897-70c23b46bec8',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '87.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '03a0f0ef-8241-4241-b897-70c23b46bec8',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '175000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Centro',
#          'slug': 'colombia-antioquia-medellín-5502103-centro'},
#         {'name': 'La candelaria',
#          'slug': ['neighbourhood-colombia-05-001-001007',
#           'colombia-antioquia-medellín-5502101-la-candelaria']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.5658187866211 6.247637748718262)',
#        'groups': [{'subgroups': {'name': 'Centro',
#           'slug': 'colombia-antioquia-medellín-5500101-centro'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7433851}}},
#    {'_index': 'fr-site-listing',
#     '_id': '4201d35c-7fa4-4ada-9dcf-d447491532fd',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '92.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '4201d35c-7fa4-4ada-9dcf-d447491532fd',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '260000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'BARRIO LAS PALMAS',
#          'slug': 'colombia-antioquia-medellin-0-barrio-las-palmas'},
#         {'name': 'Las palmas',
#          'slug': ['neighbourhood-colombia-05-001-001013',
#           'colombia-antioquia-medellín-5502007-las-palmas']},
#         {'name': 'El salvador',
#          'slug': ['neighbourhood-colombia-05-001-000901',
#           'colombia-antioquia-medellín-5502113-el-salvador']},
#         {'name': 'Bombona no.1',
#          'slug': ['neighbourhood-colombia-05-001-001012',
#           'colombia-antioquia-medellín-5502111-bomboná']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.56379699707031 6.24138069152832)',
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 6165532}}},
#    {'_index': 'fr-site-listing',
#     '_id': '97d5c198-7ca1-4f63-a192-1e85df8af695',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '37.0',
#       'rooms': {'name': '2'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '97d5c198-7ca1-4f63-a192-1e85df8af695',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Aviso Adicional',
#         'label': 'MA',
#         'slug': 'PAID_QUOTA'}],
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '1', 'id': 1},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '150000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Alnago',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Loreto',
#          'slug': 'colombia-antioquia-medellin-0-loreto'},
#         {'name': 'Loreto', 'slug': ['neighbourhood-colombia-05-001-000910']},
#         {'name': 'Asomadera no.3',
#          'slug': ['neighbourhood-colombia-05-001-000915']},
#         {'name': 'Panorama',
#          'slug': ['neighbourhood-colombia-05-001-000914']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.55716705322266 6.23033332824707)',
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7271430}}},
#    {'_index': 'fr-site-listing',
#     '_id': '45bcc478-7d65-4896-a6cd-66885c0078ae',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '72.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '45bcc478-7d65-4896-a6cd-66885c0078ae',
#       'stratum': {'name': 'Estrato 3'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '285000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Proventa Inmobiliaria',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Rodeo Alto',
#          'slug': 'colombia-antioquia-medellín-5502042-rodeo-alto'},
#         {'name': 'Belén Rincón',
#          'slug': ['neighbourhood-5502119-belen_rincon',
#           'colombia-antioquia-medellín-5502119-belén-rincón']},
#         {'name': 'Belén', 'slug': ['neighbourhood-medellin-05-belen']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.60260772705078 6.212916851043701)',
#        'groups': [{'subgroups': {'name': 'SurOccidente',
#           'slug': 'colombia-antioquia-medellín-5500105-suroccidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7694741}}},
#    {'_index': 'fr-site-listing',
#     '_id': '60311440-7ef3-4907-9f12-c3b35b48f202',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '135.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '60311440-7ef3-4907-9f12-c3b35b48f202',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '600000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Santa Fe',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Laureles',
#          'slug': 'colombia-antioquia-medellín-5502057-laureles'},
#         {'name': 'Laureles', 'slug': ['neighbourhood-medellin-05-laureles']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.59723663330078 6.246053695678711)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 5951824}}},
#    {'_index': 'fr-site-listing',
#     '_id': 'ed6a96d9-37f4-4b0d-9f27-e17cd134916e',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '177.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': 'ed6a96d9-37f4-4b0d-9f27-e17cd134916e',
#       'stratum': {'name': 'Estrato 6'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '4'},
#       'baths': {'name': '4', 'id': 4},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '1380000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Compro Casa',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'San Lucas',
#          'slug': 'colombia-antioquia-medellín-5502003-san-lucas'},
#         {'name': 'San lucas',
#          'slug': ['neighbourhood-colombia-05-001-001422',
#           'colombia-antioquia-medellín-5502003-san-lucas']},
#         {'name': 'Urbanizacion las cumbres',
#          'slug': ['neighbourhood-colombia-05-001-001439']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.56405639648438 6.1799445152282715)',
#        'groups': [{'subgroups': {'name': 'SurOriente',
#           'slug': 'colombia-antioquia-medellín-5500102-suroriente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7671570}}},
#    {'_index': 'fr-site-listing',
#     '_id': 'fe8c1269-d81a-4395-be89-e5de9ebd811c',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '185.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': 'fe8c1269-d81a-4395-be89-e5de9ebd811c',
#       'stratum': {'name': 'Estrato 4'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '4', 'id': 4},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '400000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'JAIRO OCHOA PROPIEDAD RAIZ',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Centro administrativo',
#          'slug': ['neighbourhood-colombia-05-001-001011']},
#         {'name': 'Centro',
#          'slug': 'colombia-antioquia-medellín-5502103-centro'},
#         {'name': 'Villanueva',
#          'slug': ['neighbourhood-colombia-05-001-001005']},
#         {'name': 'Villa Nueva',
#          'slug': ['neighbourhood-colombia-05-001-001005',
#           'colombia-antioquia-medellín-5502110-villa-nueva']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.56400299072266 6.252999782562256)',
#        'groups': [{'subgroups': {'name': 'Centro',
#           'slug': 'colombia-antioquia-medellín-5500101-centro'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7748902}}},
#    {'_index': 'fr-site-listing',
#     '_id': '231904d6-bd80-4347-84f9-a8b0afcb626c',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '137.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '231904d6-bd80-4347-84f9-a8b0afcb626c',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '560000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Inverkasa Inmobiliaria',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Laureles',
#          'slug': 'colombia-antioquia-medellín-5502057-laureles'}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'}],
#        'location_point': 'POINT (0.0 0.0)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'}]},
#       'fr_property_id': 7906676}}},
#    {'_index': 'fr-site-listing',
#     '_id': '7e5e06ac-d1e5-4b99-a370-c1f15822af52',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '88.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '7e5e06ac-d1e5-4b99-a370-c1f15822af52',
#       'products': [{'configuration': {'tag_name': ''},
#         'name': 'Anuncio Destacado OVI',
#         'label': 'DOV',
#         'slug': 'FEATURED_BASIC'}],
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '410000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Teubicorealestate',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Belen La Palma',
#          'slug': ['neighbourhood-5502039-belen_la_palma',
#           'colombia-antioquia-medellín-5502039-belen-la-palma']},
#         {'name': 'Laureles', 'slug': ['neighbourhood-medellin-05-laureles']},
#         {'name': 'Laureles Nogal',
#          'slug': ['neighbourhood-medellin-05-laureles_nogal']},
#         {'name': 'Belén', 'slug': ['neighbourhood-medellin-05-belen']}],
#        'cities': [{'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.60270690917969 6.230431079864502)',
#        'countries': [{'name': 'Colombia',
#          'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7614989}}},
#    {'_index': 'fr-site-listing',
#     '_id': 'c1fe24a7-9e13-4b82-b966-ba71323da365',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '75.0',
#       'rooms': {'name': '3'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': 'c1fe24a7-9e13-4b82-b966-ba71323da365',
#       'stratum': {'name': 'Estrato 4'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '280000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Santa Fe',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'La América',
#          'slug': 'colombia-antioquia-medellín-5502054-la-américa'},
#         {'name': 'La esperanza no.2',
#          'slug': ['neighbourhood-colombia-05-001-000106']},
#         {'name': 'Santo domingo savio no.1',
#          'slug': ['neighbourhood-colombia-05-001-000103']},
#         {'name': 'Granizal',
#          'slug': ['neighbourhood-colombia-05-001-000105']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.54340362548828 6.292036056518555)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 5839587}}},
#    {'_index': 'fr-site-listing',
#     '_id': '54efc67d-c942-4cee-a360-be610e0c4102',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '280.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '54efc67d-c942-4cee-a360-be610e0c4102',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '3'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '1780000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Inverkasa Inmobiliaria',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'El Poblado',
#          'slug': 'colombia-antioquia-medellín-5502014-el-poblado'},
#         {'name': 'Viviendas del Sur',
#          'slug': ['neighbourhood-itagui-viviendas_del_sur']},
#         {'name': 'Belén', 'slug': ['neighbourhood-medellin-05-belen']},
#         {'name': 'La hondonada',
#          'slug': ['neighbourhood-colombia-05-001-001621']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.60262298583984 6.202325344085693)',
#        'groups': [{'subgroups': {'name': 'SurOriente',
#           'slug': 'colombia-antioquia-medellín-5500102-suroriente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7889488}}},
#    {'_index': 'fr-site-listing',
#     '_id': '6016713e-3d42-46e4-93ab-78455e041958',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '195.0',
#       'rooms': {'name': '5'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '6016713e-3d42-46e4-93ab-78455e041958',
#       'stratum': {'name': 'Estrato 4'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '350000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Santa Fe',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'La América',
#          'slug': 'colombia-antioquia-medellín-5502054-la-américa'},
#         {'name': 'La esperanza no.2',
#          'slug': ['neighbourhood-colombia-05-001-000106']},
#         {'name': 'Santo domingo savio no.1',
#          'slug': ['neighbourhood-colombia-05-001-000103']},
#         {'name': 'Granizal',
#          'slug': ['neighbourhood-colombia-05-001-000105']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.54340362548828 6.292036056518555)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7121725}}},
#    {'_index': 'fr-site-listing',
#     '_id': '8f50bf5a-bbb2-4643-afd5-85a04f9472da',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '132.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '8f50bf5a-bbb2-4643-afd5-85a04f9472da',
#       'stratum': {'name': 'Estrato 6'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '2'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '690000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'GRUPO INMOBILIARIO CABAL',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Conquistadores',
#          'slug': 'colombia-antioquia-medellín-5502061-conquistadores'}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'}],
#        'location_point': 'POINT (0.0 0.0)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'}]},
#       'fr_property_id': 7824264}}},
#    {'_index': 'fr-site-listing',
#     '_id': '10d5e9c2-6c62-489a-9349-a642f59c7402',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '175.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '10d5e9c2-6c62-489a-9349-a642f59c7402',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '1150000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'GRUPO INMOBILIARIO CABAL',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Conquistadores',
#          'slug': 'colombia-antioquia-medellín-5502061-conquistadores'}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'}],
#        'location_point': 'POINT (0.0 0.0)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'}]},
#       'fr_property_id': 7824280}}},
#    {'_index': 'fr-site-listing',
#     '_id': '91a08b43-10de-4fa4-a4f4-284952cf0224',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '110.0',
#       'rooms': {'name': '1'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '91a08b43-10de-4fa4-a4f4-284952cf0224',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '2'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '500000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'GRUPO INMOBILIARIO CABAL',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Conquistadores',
#          'slug': 'colombia-antioquia-medellín-5502061-conquistadores'}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'}],
#        'location_point': 'POINT (0.0 0.0)',
#        'groups': [{'subgroups': {'name': 'Occidente',
#           'slug': 'colombia-antioquia-medellín-5500106-occidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'}]},
#       'fr_property_id': 7824197}}},
#    {'_index': 'fr-site-listing',
#     '_id': '7465c231-7c61-46b3-85ea-eb0ecc0f8342',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '72.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '7465c231-7c61-46b3-85ea-eb0ecc0f8342',
#       'stratum': {'name': 'Estrato 2'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': 'Sin especificar'},
#       'baths': {'name': '2', 'id': 2},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '200000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Arrendamientos Santa Fe',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'Robledo',
#          'slug': 'colombia-antioquia-medellín-5502070-robledo'},
#         {'name': 'Villa flora',
#          'slug': ['neighbourhood-colombia-05-001-000712']},
#         {'name': 'Bello horizonte',
#          'slug': ['neighbourhood-colombia-05-001-000707']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.59044647216797 6.280363082885742)',
#        'groups': [{'subgroups': {'name': 'NorOccidente',
#           'slug': 'colombia-antioquia-medellín-5500104-noroccidente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 6893017}}},
#    {'_index': 'fr-site-listing',
#     '_id': '0783f270-bb9f-406b-94e0-e7eeb57cf65f',
#     '_score': 0.0,
#     '_source': {'listing': {'area': '131.0',
#       'rooms': {'name': '4'},
#       'is_new': False,
#       'title': 'Apartamento en Venta',
#       'property_id': '0783f270-bb9f-406b-94e0-e7eeb57cf65f',
#       'stratum': {'name': 'Estrato 5'},
#       'offer': [{'name': 'Venta'}],
#       'garages': {'name': '1'},
#       'baths': {'name': '3', 'id': 3},
#       'min_price': '0',
#       'fr_parent_property_id': 0,
#       'price': '500000000.0',
#       'min_area': '0',
#       'client': {'company_name': 'Conectar Inmobiliaria',
#        'last_name': '',
#        'client_type': 'BROKER',
#        'first_name': ''},
#       'property_type': [{'name': 'Apartamento'}],
#       'locations': {'neighbourhoods': [{'name': 'El Poblado',
#          'slug': 'colombia-antioquia-medellín-5502014-el-poblado'},
#         {'name': 'Urbanizacion bosques de la aguacata',
#          'slug': ['neighbourhood-colombia-05-001-001430']},
#         {'name': 'Santa maria de los angeles',
#          'slug': ['neighbourhood-colombia-05-001-001421',
#           'colombia-antioquia-medellín-5502006-santa-maría-de-los-ángeles']}],
#        'cities': [{'name': 'Medellín',
#          'slug': 'colombia-antioquia-5500006-medellín'},
#         {'name': 'Medellín',
#          'slug': ['city-colombia-05-001',
#           'colombia-antioquia-5500006-medellín']}],
#        'location_point': 'POINT (-75.5807876586914 6.193251609802246)',
#        'groups': [{'subgroups': {'name': 'SurOriente',
#           'slug': 'colombia-antioquia-medellín-5500102-suroriente'},
#          'name': 'Zonas',
#          'slug': 'zonas'}],
#        'countries': [{'name': 'Colombia', 'slug': 'colombia'},
#         {'name': 'Colombia', 'slug': ['country-48-colombia', 'colombia']}],
#        'states': [{'name': 'Antioquia', 'slug': 'colombia-antioquia'},
#         {'name': 'Antioquia',
#          'slug': ['state-colombia-05-antioquia', 'colombia-antioquia']}]},
#       'fr_property_id': 7676748}}}]},
#  'cache': {'id': 'ListingDocument-f466d9cc0037f5bff7e96f90a765897dca98b93f',
#   'time_type': 'minutes',
#   'time_data': 5,
#   'datetime': '2023-10-18 12:22:33'}}

# %%
def obtener_datos(offset):
    json_data['fields']['offset'] = offset
    response = requests.post('https://api.fincaraiz.com.co/document/api/1.0/listing/search', headers=headers, json=json_data, timeout=10)
    data = response.json()
    return data.get('hits', {}).get('hits', [])

num_paginas = 1 #Esta es la máxima cantidad de páginas que podemos extraer

properties_data = []

offset = 0

for pagina in range(num_paginas):
    hits = obtener_datos(offset)

    if not hits:
        break

    for hit in hits:
        source = hit['_source']['listing']
        property_info = {
            'area': source['area'],
            'rooms': source['rooms']['name'],
            'is_new': source['is_new'],
            'property_id': source['property_id'],
            'garages': source['garages']['name'],
            'stratum': source['stratum']['name'],
            'property_type': source['property_type'][0]['name'],
            'baths': source['baths']['name'],
            'min_price': source['min_price'],
            'price': source['price'],
            'company_name': source['client']['company_name'],
            'client_type': source['client']['client_type'],
            'neighbourhood': source['locations']['neighbourhoods'][0]['name'],
            'city': source['locations']['cities'][0]['name'],
            'latitude': source['locations']['location_point'].split()[1][1:],
            'longitude': source['locations']['location_point'].split('(')[1].split()[1].rstrip(')'),
            'zone': source['locations'].get('groups', [{'subgroups': {'name': 'No Zone'}}])[0]['subgroups']['name']
        }
        properties_data.append(property_info)

    offset += 25

df = pd.DataFrame(properties_data)
df.drop_duplicates(subset='property_id', keep='first', inplace=True)

# %%
df
# Out:
#      area rooms  is_new                           property_id  \
# 0    50.0     3   False  5b59f4a2-1208-481a-b451-80fb02fe2e1b
# 1   185.0     3   False  4275fdf4-8382-43f4-8e4b-f330031d50a8
# 2    65.0     3   False  3840da3b-dffd-4c79-8ce0-6e40ac1da3be
# 3    37.0     2   False  0da20ec5-8e25-4e7a-9e04-f1e33536f8b0
# 4    95.0     3   False  877904f1-7876-4dd6-b858-457b62018eb6
# 5    87.0     3   False  03a0f0ef-8241-4241-b897-70c23b46bec8
# 6    37.0     2   False  97d5c198-7ca1-4f63-a192-1e85df8af695
# 7    72.0     3   False  45bcc478-7d65-4896-a6cd-66885c0078ae
# 8   135.0     3   False  60311440-7ef3-4907-9f12-c3b35b48f202
# 9   177.0     3   False  ed6a96d9-37f4-4b0d-9f27-e17cd134916e
# 10  185.0     4   False  fe8c1269-d81a-4395-be89-e5de9ebd811c
# 11  137.0     3   False  231904d6-bd80-4347-84f9-a8b0afcb626c
# 12   88.0     3   False  7e5e06ac-d1e5-4b99-a370-c1f15822af52
# 13   75.0     3   False  c1fe24a7-9e13-4b82-b966-ba71323da365
# 14  280.0     4   False  54efc67d-c942-4cee-a360-be610e0c4102
# 15  195.0     5   False  6016713e-3d42-46e4-93ab-78455e041958
# 16   72.0     4   False  7465c231-7c61-46b3-85ea-eb0ecc0f8342
# 17  131.0     4   False  0783f270-bb9f-406b-94e0-e7eeb57cf65f
# 18   63.0     3   False  13d0a1f1-6d7d-475f-8912-958c1b7a4fc9
# 19   88.0     3   False  cee326a9-83e3-4d3a-907d-ca713f50122e
# 20  102.0     3   False  f0ae650e-ab9b-4b2a-8983-998ae3c4839d
# 21   50.0     2   False  328587f5-bf08-444d-9203-76f0dec7087b
# 22  106.0     3   False  4474d79f-101a-40ba-8ee5-efc310c47dac
# 23  260.0     5   False  e4a54e96-e541-4784-b9d5-6b9832adbee7
# 24   85.0     3   False  2ade28b8-72f9-4970-9cfc-a241266e8f73
#
#             garages    stratum property_type baths min_price         price  \
# 0   Sin especificar  Estrato 3   Apartamento     1         0   210000000.0
# 1                 2  Estrato 6   Apartamento     3         0  1040000000.0
# 2   Sin especificar  Estrato 2   Apartamento     1         0   165000000.0
# 3   Sin especificar  Estrato 3   Apartamento     1         0   145000000.0
# 4                 1  Estrato 3   Apartamento     2         0   300000000.0
# 5   Sin especificar  Estrato 3   Apartamento     2         0   175000000.0
# 6   Sin especificar  Estrato 3   Apartamento     1         0   150000000.0
# 7                 1  Estrato 3   Apartamento     2         0   285000000.0
# 8                 1  Estrato 5   Apartamento     2         0   600000000.0
# 9                 4  Estrato 6   Apartamento     4         0  1380000000.0
# 10                1  Estrato 4   Apartamento     4         0   400000000.0
# 11                1  Estrato 5   Apartamento     3         0   560000000.0
# 12                1  Estrato 5   Apartamento     2         0   410000000.0
# 13  Sin especificar  Estrato 4   Apartamento     2         0   280000000.0
# 14                3  Estrato 5   Apartamento     3         0  1780000000.0
# 15  Sin especificar  Estrato 4   Apartamento     3         0   350000000.0
# 16  Sin especificar  Estrato 2   Apartamento     2         0   200000000.0
# 17                1  Estrato 5   Apartamento     3         0   500000000.0
# 18                1  Estrato 4   Apartamento     2         0   354000000.0
# 19                1  Estrato 3   Apartamento     2         0   420000000.0
# 20                1  Estrato 5   Apartamento     2         0   370000000.0
# 21                1  Estrato 3   Apartamento     2         0   205000000.0
# 22                2  Estrato 5   Apartamento     4         0   720000000.0
# 23                2  Estrato 6   Apartamento     5         0   950000000.0
# 24  Sin especificar  Estrato 5   Apartamento     3         0   350000000.0
#
#                                        company_name client_type  \
# 0                             Arrendamientos Alnago      BROKER
# 1                  ASESORIA INMOBILIARIA Y PROYECTO      BROKER
# 2                             Arrendamientos Alnago      BROKER
# 3                             Arrendamientos Alnago      BROKER
# 4                             Arrendamientos Alnago      BROKER
# 5                             Arrendamientos Alnago      BROKER
# 6                             Arrendamientos Alnago      BROKER
# 7                             Proventa Inmobiliaria      BROKER
# 8                           Arrendamientos Santa Fe      BROKER
# 9                                       Compro Casa      BROKER
# 10                       JAIRO OCHOA PROPIEDAD RAIZ      BROKER
# 11                           Inverkasa Inmobiliaria      BROKER
# 12                                Teubicorealestate      BROKER
# 13                          Arrendamientos Santa Fe      BROKER
# 14                           Inverkasa Inmobiliaria      BROKER
# 15                          Arrendamientos Santa Fe      BROKER
# 16                          Arrendamientos Santa Fe      BROKER
# 17                            Conectar Inmobiliaria      BROKER
# 18                          Arrendamientos Santa Fe      BROKER
# 19                            Unión Inmobiliaria PR      BROKER
# 20                          Arrendamientos Santa Fe      BROKER
# 21                            Propiedades & Avaluos      BROKER
# 22  Ileana.Consultora Inmobiliaria. Propiedad Raíz.      BROKER
# 23                          Arrendamientos Santa Fe      BROKER
# 24                          Arrendamientos Santa Fe      BROKER
#
#             neighbourhood      city            latitude           longitude  \
# 0                Aranjuez  Medellín  -75.55608367919922   6.281782627105713
# 1              Las palmas  Medellín  -75.55524826049805  6.1805192071347825
# 2                Manrique  Medellín   -75.5600357055664   6.287129878997803
# 3                  Loreto  Medellín  -75.55716705322266    6.23033332824707
# 4           Villa Hermosa  Medellín  -75.54766082763672   6.275725841522217
# 5                  Centro  Medellín   -75.5658187866211   6.247637748718262
# 6                  Loreto  Medellín  -75.55716705322266    6.23033332824707
# 7              Rodeo Alto  Medellín  -75.60260772705078   6.212916851043701
# 8                Laureles  Medellín  -75.59723663330078   6.246053695678711
# 9               San Lucas  Medellín  -75.56405639648438  6.1799445152282715
# 10  Centro administrativo  Medellín  -75.56400299072266   6.252999782562256
# 11               Laureles  Medellín                 0.0                 0.0
# 12         Belen La Palma  Medellín  -75.60270690917969   6.230431079864502
# 13             La América  Medellín  -75.54340362548828   6.292036056518555
# 14             El Poblado  Medellín  -75.60262298583984   6.202325344085693
# 15             La América  Medellín  -75.54340362548828   6.292036056518555
# 16                Robledo  Medellín  -75.59044647216797   6.280363082885742
# 17             El Poblado  Medellín   -75.5807876586914   6.193251609802246
# 18                Robledo  Medellín  -75.59024810791016   6.271875381469727
# 19   San Antonio de Prado  Medellín  -75.61290740966797   6.150283336639404
# 20               Calasanz  Medellín  -75.54365539550781   6.291950702667236
# 21  Centro administrativo  Medellín  -75.57369315395512   6.242587419580989
# 22               Laureles  Medellín  -75.60000610351562   6.250190258026123
# 23             El Poblado  Medellín  -75.57266235351562   6.181459903717041
# 24          La Castellana  Medellín  -75.60604095458984    6.24189567565918
#
#             zone
# 0     NorOriente
# 1        No Zone
# 2     NorOriente
# 3        No Zone
# 4     NorOriente
# 5         Centro
# 6        No Zone
# 7   SurOccidente
# 8      Occidente
# 9     SurOriente
# 10        Centro
# 11     Occidente
# 12       No Zone
# 13     Occidente
# 14    SurOriente
# 15     Occidente
# 16  NorOccidente
# 17    SurOriente
# 18  NorOccidente
# 19    SurOriente
# 20  NorOccidente
# 21       No Zone
# 22     Occidente
# 23    SurOriente
# 24     Occidente

# %%
df.set_index('property_id').head()
# Out:
#                                        area rooms  is_new          garages  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b   50.0     3   False  Sin especificar
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2   67.0     3   False                1
# 7dd6770d-b5f2-4106-81bd-94c39df2999f   96.0     3   False  Sin especificar
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  185.0     3   False                2
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be   65.0     3   False  Sin especificar
#
#                                         stratum property_type baths min_price  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b  Estrato 3   Apartamento     1         0
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2  Estrato 3   Apartamento     2         0
# 7dd6770d-b5f2-4106-81bd-94c39df2999f  Estrato 3   Apartamento     2         0
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  Estrato 6   Apartamento     3         0
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be  Estrato 2   Apartamento     1         0
#
#                                              price  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b   210000000.0
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2   340000000.0
# 7dd6770d-b5f2-4106-81bd-94c39df2999f   295000000.0
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  1040000000.0
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be   165000000.0
#
#                                                           company_name  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b             Arrendamientos Alnago
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2             Arrendamientos Alnago
# 7dd6770d-b5f2-4106-81bd-94c39df2999f             Arrendamientos Alnago
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  ASESORIA INMOBILIARIA Y PROYECTO
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be             Arrendamientos Alnago
#
#                                      client_type  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b      BROKER
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2      BROKER
# 7dd6770d-b5f2-4106-81bd-94c39df2999f      BROKER
# 4275fdf4-8382-43f4-8e4b-f330031d50a8      BROKER
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be      BROKER
#
#                                                           neighbourhood  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b                           Aranjuez
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2  Urbanizacion praderas de guayabal
# 7dd6770d-b5f2-4106-81bd-94c39df2999f                           Aranjuez
# 4275fdf4-8382-43f4-8e4b-f330031d50a8                         Las palmas
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be                           Manrique
#
#                                           city            latitude  \
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b  Medellín  -75.55608367919922
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2    Itaguí  -75.59156036376953
# 7dd6770d-b5f2-4106-81bd-94c39df2999f  Medellín   -75.5658187866211
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  Medellín  -75.55524826049805
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be  Medellín   -75.5600357055664
#
#                                                longitude        zone
# property_id
# 5b59f4a2-1208-481a-b451-80fb02fe2e1b   6.281782627105713  NorOriente
# acbbcf61-3022-4d34-87b9-d240ae7cb7b2   6.235456943511963     No Zone
# 7dd6770d-b5f2-4106-81bd-94c39df2999f   6.247637748718262  NorOriente
# 4275fdf4-8382-43f4-8e4b-f330031d50a8  6.1805192071347825     No Zone
# 3840da3b-dffd-4c79-8ce0-6e40ac1da3be   6.287129878997803  NorOriente

# %%
df.to_csv('data/medellin.csv',index = False)
